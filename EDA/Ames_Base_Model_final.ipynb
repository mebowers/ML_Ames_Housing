# %% [markdown]
# # Summary of previous data cleaning:
#
# From **Ames_Data_Cleaning.ipynb**, the following modifications were made to the Ames dataset:
#
# **Data Types**
# - OverallQual and OverallCond reclassified as ordinal datatypes (per data dictionary)
# - MSSubClass reclassified as categorical (nominal) datatype
# - MoSold and YrSold redefined as categorical datatypes for modeling options
# - Other date features remain numeric types, to prevent dimensionality problems when ordinal encoding
# - GarageYrBlt changed from 'float' to 'int', after imputation of missing values, to match other date features.
#
#
# **Missing Data and Imputation**
# - Numerical Features:
#     - After exploring relationship between GarageYrBlt and YearBuilt, imputed missing values with YearBuilt
#     - After evaluating relationship between LotArea and LotFrontage, imputed LotFrontage with median
#     - Imputed remaining numerical features with median values (meadian values are the same as the mode values for discrete features)
# - Categorical Features:
#     - Imputed missing Electrical value with mode value
#     - After evaluating Garage features, imputed missing values with 'None'
#     - Imputed remaining categorical features with 'None'
#
#
# **Outliers**
#  - Looked at GrLivArea vs. SalePrice for ames with and without the 2 extreme GrLivArea values. I did not see any significant impact on the two models and did not consider them worth removing. **This is contrary to what De Cock suggests in his paper**
#
# **ames_clean.pkl** include these changes.

# %% [markdown]
# # Contents
#
# [Numerical Models](#Numerical-Models)
#
# no categoricalfeatures
#
# - num linear-linear model, including mc features
# - num linear-linear model, no mc features
# - num log-linear model, no mc features
# - num log-log (partial) model, log transforming most highly skewed features:
#     - LotArea
#     - MasVnrArea
#     - WoodDeckSF
#     - OpenPorchSF
#     - EnclosedPorch
#     - 3SsnPorch
#     - ScreenPorch
#
#
# [Numerical and Categorical Models](#Numerical-and-Categorical-Models)
#
# - num-cat linear-linear model, all df features
# - num-cat log-linear model, without mc, composite features
#
# **Model summaries in notebooks_results**
#
# [Resources](#Resources)

# %%
# libraries
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.model_selection import KFold

from sklearn.linear_model import LinearRegression

# %%
# setting to enable full viewing of cell output
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Import raw data, if needed for comparison.

# %%
ames_raw = pd.read_csv('Ames_Housing_Price_Data.csv', index_col=0).reset_index()
ames_raw.drop(columns=['index'], inplace=True)
ames_raw.head(2)
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 0  909176150        856     126000          30       RL          NaN     7890
# 1  905476230       1049     139500         120       RL         42.0     4235
#
#   Street Alley LotShape  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0   Pave   NaN      Reg  ...         166        0    NaN   NaN         NaN
# 1   Pave   NaN      Reg  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold SaleType  SaleCondition
# 0       0      3   2010      WD          Normal
# 1       0      2   2009      WD          Normal
#
# [2 rows x 81 columns]

# %% [markdown]
# ### Import cleaned data: ames_clean.pkl

# %%
ames = pd.read_pickle('ames_clean.pkl')

# %%
ames.isnull().sum().sum()
# Out:
# 0

# %%
ames.columns
# Out:
# Index(['GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning', 'LotFrontage',
#        'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# ## Define numerical features

# %%
numerical_features = ames.select_dtypes(include=['float64', 'int64'])
numerical_features
# Out:
#       GrLivArea  SalePrice  LotFrontage  LotArea  YearBuilt  YearRemodAdd  \
# 0           856     126000         68.0     7890       1939          1950
# 1          1049     139500         42.0     4235       1984          1984
# 2          1001     124900         60.0     6060       1930          2007
# 3          1039     114000         80.0     8146       1900          2003
# 4          1665     227000         70.0     8400       2001          2001
# ...         ...        ...          ...      ...        ...           ...
# 2575        952     121000         68.0     8854       1916          1950
# 2576       1733     139600         68.0    13680       1955          1955
# 2577       2002     145000         82.0     6270       1949          1950
# 2578       1842     217500         68.0     8826       2000          2000
# 2579       1911     215000         80.0     9554       1993          1994
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  GarageYrBlt  \
# 0            0.0       238.0         0.0      618.0  ...         1939
# 1          149.0       552.0       393.0      104.0  ...         1984
# 2            0.0       737.0         0.0      100.0  ...         1930
# 3            0.0         0.0         0.0      405.0  ...         1940
# 4            0.0       643.0         0.0      167.0  ...         2001
# ...          ...         ...         ...        ...  ...          ...
# 2575         0.0         0.0         0.0      952.0  ...         1916
# 2576         0.0         0.0         0.0        0.0  ...         1955
# 2577         0.0       284.0         0.0      717.0  ...         1949
# 2578       144.0       841.0         0.0      144.0  ...         2000
# 2579       125.0       380.0         0.0      397.0  ...         1993
#
#       GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 0            2.0       399.0           0            0              0
# 1            1.0       266.0           0          105              0
# 2            1.0       216.0         154            0             42
# 3            1.0       281.0           0            0            168
# 4            2.0       528.0           0           45              0
# ...          ...         ...         ...          ...            ...
# 2575         1.0       192.0           0           98              0
# 2576         2.0       452.0           0            0              0
# 2577         3.0       871.0           0            0              0
# 2578         2.0       486.0         193           96              0
# 2579         2.0       471.0         182           81              0
#
#       3SsnPorch  ScreenPorch  PoolArea  MiscVal
# 0             0          166         0        0
# 1             0            0         0        0
# 2            86            0         0        0
# 3             0          111         0        0
# 4             0            0         0        0
# ...         ...          ...       ...      ...
# 2575          0           40         0        0
# 2576          0            0         0        0
# 2577          0            0         0        0
# 2578          0            0         0        0
# 2579          0            0         0        0
#
# [2580 rows x 32 columns]

# %%
numerical_features_list = ames.select_dtypes(include=['float64', 'int64']).columns
numerical_features_list
# Out:
# Index(['GrLivArea', 'SalePrice', 'LotFrontage', 'LotArea', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal'],
#       dtype='object')

# %% [markdown]
# **Note:** These are the correct, 32 numerical features

# %% [markdown]
# # Numerical Models
# [Contents](#Contents)
#
# no categorical features
#
# ### numerical model with all numerical features, including multicollinear features

# %%
# define features and target 
X = numerical_features.drop('SalePrice', axis = 1)
y = ames['SalePrice']

# %%
# Set up preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', X.columns.to_list())
])

# fit the model
model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', LinearRegression())
    ])

model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['GrLivArea', 'LotFrontage',
#                                                    'LotArea', 'YearBuilt',
#                                                    'YearRemodAdd', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvGrd', 'Fireplaces',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea', 'WoodDeckSF',
#                                                    'OpenPorchSF',
#                                                    'EnclosedPorch', '3SsnPorch',
#                                                    'ScreenPorch', 'PoolArea', ...])])),
#                 ('regressor', LinearRegression())])

# %%
# evaluate the model
cv_scores = cross_val_score(model, X, y)

mean_cv_score = float(round(cv_scores.mean(), 4))
print(f'numerical linear-linear model, including mc features, no categorical')
print(f'mean cv score: {mean_cv_score}')
print(f'cv scores: {cv_scores}')

# Store model data for summary
# Initialize once to store results
notebook_results = []

# append notebook_results
notebook_results.append({
    'Scenario': 'num linear-linear model, including mc features',
    'Mean CV Score': mean_cv_score,
    'CV Scores': cv_scores.tolist()  # Convert to list for better display
})
# Out:
# numerical linear-linear model, including mc features, no categorical
# mean cv score: 0.8277
# cv scores: [0.79384382 0.8336217  0.85686165 0.82131624 0.83287847]

# %%
# notebook_results

# %% [markdown]
# ### drop composite, multicollinear features

# %%
# drop target and define features for base model
base_features = numerical_features.drop(columns=['SalePrice', 'MiscVal', 'TotalBsmtSF', 'GrLivArea'], axis=1)
base_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  Fireplaces  GarageYrBlt  \
# 0         0.0      618.0       856         0  ...           1         1939
# 1       393.0      104.0      1049         0  ...           0         1984
#
#    GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         2.0       399.0           0            0              0          0
# 1         1.0       266.0           0          105              0          0
#
#    ScreenPorch  PoolArea
# 0          166         0
# 1            0         0
#
# [2 rows x 28 columns]

# %%
# Define base features list
base_features_list = base_features.columns.to_list()
print(f'number of base features (without target and 3 multicollinear features): {len(base_features_list)}')
# Out:
# number of base features (without target and 3 multicollinear features): 28

# %%
# define features and target for modeling
X = base_features
y = ames['SalePrice']

# %%
# Set up preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', base_features_list)
])

# fit the model
model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', LinearRegression())
    ])

model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['LotFrontage', 'LotArea',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvGrd', 'Fireplaces',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea', 'WoodDeckSF',
#                                                    'OpenPorchSF',
#                                                    'EnclosedPorch', '3SsnPorch',
#                                                    'ScreenPorch',
#                                                    'PoolArea'])])),
#                 ('regressor', LinearRegression())])

# %%
# evaluate the model
cv_scores = cross_val_score(model, X, y)

# %%
mean_cv_score = float(round(cv_scores.mean(), 4))
print(f'numerical linear-linear model without MiscVal, TotalBsmtSF, and GrLivArea')
print(f'mean cv score: {mean_cv_score}')
print(f'cv scores: {cv_scores}')
# Out:
# numerical linear-linear model without MiscVal, TotalBsmtSF, and GrLivArea
# mean cv score: 0.8278
# cv scores: [0.79418863 0.83366325 0.85697319 0.82128648 0.83308856]

# %%
# append notebook_results
notebook_results.append({
    'Scenario': 'num linear-linear model, no mc features (MiscVal, TotalBsmtSF, and GrLivArea)',
    'Mean CV Score': mean_cv_score,
    'CV Scores': cv_scores.tolist()  # Convert to list for better display
})

# %%
# notebook_results

# %% [markdown]
# ## log-linear base model

# %%
# define features and target for modeling
X = base_features
y = ames['SalePrice']

# %%
# Set up preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', base_features_list)
])

# %%
# fit the model
model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', LinearRegression())
    ])

# %%
model.fit(X, np.log10(y))
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['LotFrontage', 'LotArea',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvGrd', 'Fireplaces',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea', 'WoodDeckSF',
#                                                    'OpenPorchSF',
#                                                    'EnclosedPorch', '3SsnPorch',
#                                                    'ScreenPorch',
#                                                    'PoolArea'])])),
#                 ('regressor', LinearRegression())])

# %%
# evaluate the model
cv_scores_log = cross_val_score(model, X, np.log10(y))

# %%
mean_cv_score_log = float(round(cv_scores_log.mean(), 4))
print(f'numerical log-linear model without MiscVal, TotalBsmtSF, and GrLivArea')
print(f'mean cv score: {mean_cv_score_log}')
print(f'cv scores: {cv_scores_log}')
# Out:
# numerical log-linear model without MiscVal, TotalBsmtSF, and GrLivArea
# mean cv score: 0.8471
# cv scores: [0.78969666 0.85385931 0.87261997 0.85933034 0.86020114]

# %%
# append notebook_results
notebook_results.append({
    'Scenario': 'num log-linear model, no mc features (MiscVal, TotalBsmtSF, and GrLivArea)',
    'Mean CV Score': mean_cv_score_log,
    'CV Scores': cv_scores_log.tolist()  # Convert to list for better display
})

# %%
# notebook_results

# %% [markdown]
# ### log-log model
# numerical model performance with log transformation of a few, highly skewed features:
#
# - LotArea
# - MasVnrArea
#
# - WoodDeckSF
# - OpenPorchSF
# - EnclosedPorch
# - 3SsnPorch
# - ScreenPorch

# %%
log_features = base_features[['LotArea', 'MasVnrArea', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch']].copy()
non_log_features = base_features[['LotFrontage', 'YearBuilt', 'YearRemodAdd',
       'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
       'GarageYrBlt', 'GarageCars', 'GarageArea', 'PoolArea']].copy()
non_log_features
# Out:
#       LotFrontage  YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0            68.0       1939          1950       238.0         0.0      618.0
# 1            42.0       1984          1984       552.0       393.0      104.0
# 2            60.0       1930          2007       737.0         0.0      100.0
# 3            80.0       1900          2003         0.0         0.0      405.0
# 4            70.0       2001          2001       643.0         0.0      167.0
# ...           ...        ...           ...         ...         ...        ...
# 2575         68.0       1916          1950         0.0         0.0      952.0
# 2576         68.0       1955          1955         0.0         0.0        0.0
# 2577         82.0       1949          1950       284.0         0.0      717.0
# 2578         68.0       2000          2000       841.0         0.0      144.0
# 2579         80.0       1993          1994       380.0         0.0      397.0
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  ...  FullBath  HalfBath  \
# 0          856         0             0           1.0  ...         1         0
# 1         1049         0             0           1.0  ...         2         0
# 2         1001         0             0           0.0  ...         1         0
# 3          717       322             0           0.0  ...         1         0
# 4          810       855             0           1.0  ...         2         1
# ...        ...       ...           ...           ...  ...       ...       ...
# 2575       952         0             0           0.0  ...         1         0
# 2576      1733         0             0           0.0  ...         2         0
# 2577      1001      1001             0           0.0  ...         2         0
# 2578       985       857             0           1.0  ...         2         1
# 2579      1065       846             0           0.0  ...         2         1
#
#       BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# 0                2             1             4           1         1939
# 1                2             1             5           0         1984
# 2                2             1             5           0         1930
# 3                2             1             6           0         1940
# 4                3             1             6           0         2001
# ...            ...           ...           ...         ...          ...
# 2575             2             1             4           1         1916
# 2576             4             1             8           1         1955
# 2577             4             2             8           0         1949
# 2578             3             1             7           1         2000
# 2579             3             1             8           1         1993
#
#       GarageCars  GarageArea  PoolArea
# 0            2.0       399.0         0
# 1            1.0       266.0         0
# 2            1.0       216.0         0
# 3            1.0       281.0         0
# 4            2.0       528.0         0
# ...          ...         ...       ...
# 2575         1.0       192.0         0
# 2576         2.0       452.0         0
# 2577         3.0       871.0         0
# 2578         2.0       486.0         0
# 2579         2.0       471.0         0
#
# [2580 rows x 21 columns]

# %%
log_features_list = log_features.columns.to_list()
non_log_features_list = non_log_features.columns.to_list()
log_features_list
# Out:
# ['LotArea',
#  'MasVnrArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch']

# %%
X1 = ames[log_features_list].join(ames[non_log_features_list])
X1
# Out:
#       LotArea  MasVnrArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0        7890         0.0           0            0              0          0
# 1        4235       149.0           0          105              0          0
# 2        6060         0.0         154            0             42         86
# 3        8146         0.0           0            0            168          0
# 4        8400         0.0           0           45              0          0
# ...       ...         ...         ...          ...            ...        ...
# 2575     8854         0.0           0           98              0          0
# 2576    13680         0.0           0            0              0          0
# 2577     6270         0.0           0            0              0          0
# 2578     8826       144.0         193           96              0          0
# 2579     9554       125.0         182           81              0          0
#
#       ScreenPorch  LotFrontage  YearBuilt  YearRemodAdd  ...  FullBath  \
# 0             166         68.0       1939          1950  ...         1
# 1               0         42.0       1984          1984  ...         2
# 2               0         60.0       1930          2007  ...         1
# 3             111         80.0       1900          2003  ...         1
# 4               0         70.0       2001          2001  ...         2
# ...           ...          ...        ...           ...  ...       ...
# 2575           40         68.0       1916          1950  ...         1
# 2576            0         68.0       1955          1955  ...         2
# 2577            0         82.0       1949          1950  ...         2
# 2578            0         68.0       2000          2000  ...         2
# 2579            0         80.0       1993          1994  ...         2
#
#       HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0            0             2             1             4           1
# 1            0             2             1             5           0
# 2            0             2             1             5           0
# 3            0             2             1             6           0
# 4            1             3             1             6           0
# ...        ...           ...           ...           ...         ...
# 2575         0             2             1             4           1
# 2576         0             4             1             8           1
# 2577         0             4             2             8           0
# 2578         1             3             1             7           1
# 2579         1             3             1             8           1
#
#       GarageYrBlt  GarageCars  GarageArea  PoolArea
# 0            1939         2.0       399.0         0
# 1            1984         1.0       266.0         0
# 2            1930         1.0       216.0         0
# 3            1940         1.0       281.0         0
# 4            2001         2.0       528.0         0
# ...           ...         ...         ...       ...
# 2575         1916         1.0       192.0         0
# 2576         1955         2.0       452.0         0
# 2577         1949         3.0       871.0         0
# 2578         2000         2.0       486.0         0
# 2579         1993         2.0       471.0         0
#
# [2580 rows x 28 columns]

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
# helper function for handling log10 of zero values
def log10_1p(x):
    return np.log10(1 + x)

# %%
# Set up preprocessor
preprocessor1 = ColumnTransformer(
    transformers=[
        ('log', FunctionTransformer(log10_1p, validate=False), log_features_list),
        ('no_log', 'passthrough', non_log_features_list)
])

# %%
# fit the model
model1 = Pipeline(
    steps=[
        ('preprocessor1', preprocessor1),
        ('regressor', LinearRegression())
    ])

# %%
model1.fit(X1, np.log10(y))
# Out:
# Pipeline(steps=[('preprocessor1',
#                  ColumnTransformer(transformers=[('log',
#                                                   FunctionTransformer(func=<function log10_1p at 0x17772c040>),
#                                                   ['LotArea', 'MasVnrArea',
#                                                    'WoodDeckSF', 'OpenPorchSF',
#                                                    'EnclosedPorch', '3SsnPorch',
#                                                    'ScreenPorch']),
#                                                  ('no_log', 'passthrough',
#                                                   ['LotFrontage', 'YearBuilt',
#                                                    'YearRemodAdd', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvGrd', 'Fireplaces',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea',
#                                                    'PoolArea'])])),
#                 ('regressor', LinearRegression())])

# %%
X1[log_features_list]
# Out:
#       LotArea  MasVnrArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0        7890         0.0           0            0              0          0
# 1        4235       149.0           0          105              0          0
# 2        6060         0.0         154            0             42         86
# 3        8146         0.0           0            0            168          0
# 4        8400         0.0           0           45              0          0
# ...       ...         ...         ...          ...            ...        ...
# 2575     8854         0.0           0           98              0          0
# 2576    13680         0.0           0            0              0          0
# 2577     6270         0.0           0            0              0          0
# 2578     8826       144.0         193           96              0          0
# 2579     9554       125.0         182           81              0          0
#
#       ScreenPorch
# 0             166
# 1               0
# 2               0
# 3             111
# 4               0
# ...           ...
# 2575           40
# 2576            0
# 2577            0
# 2578            0
# 2579            0
#
# [2580 rows x 7 columns]

# %%
log_transformed_data = \
    model1.named_steps['preprocessor1'].named_transformers_['log'].transform(X1[log_features_list])
log_transformed_data
# Out:
#        LotArea  MasVnrArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0     3.897132    0.000000    0.000000     0.000000       0.000000   0.000000
# 1     3.626956    2.176091    0.000000     2.025306       0.000000   0.000000
# 2     3.782544    0.000000    2.190332     0.000000       1.633468   1.939519
# 3     3.910998    0.000000    0.000000     0.000000       2.227887   0.000000
# 4     3.924331    0.000000    0.000000     1.662758       0.000000   0.000000
# ...        ...         ...         ...          ...            ...        ...
# 2575  3.947189    0.000000    0.000000     1.995635       0.000000   0.000000
# 2576  4.136118    0.000000    0.000000     0.000000       0.000000   0.000000
# 2577  3.797337    0.000000    0.000000     0.000000       0.000000   0.000000
# 2578  3.945813    2.161368    2.287802     1.986772       0.000000   0.000000
# 2579  3.980231    2.100371    2.262451     1.913814       0.000000   0.000000
#
#       ScreenPorch
# 0        2.222716
# 1        0.000000
# 2        0.000000
# 3        2.049218
# 4        0.000000
# ...           ...
# 2575     1.612784
# 2576     0.000000
# 2577     0.000000
# 2578     0.000000
# 2579     0.000000
#
# [2580 rows x 7 columns]

# %%
# evaluate the model
cv1_scores_log = cross_val_score(model1, X1, np.log10(y))
cv1_scores_log
# Out:
# array([0.79006354, 0.85502   , 0.87826501, 0.86494615, 0.8651429 ])

# %%
mean_cv1_score_log = float(round(cv1_scores_log.mean(), 4))
print(f'numerical log-log (partial: most highly skewed features log transformed) model without MiscVal, TotalBsmtSF, and GrLivArea')
print(f'mean cv score log-log(partial) model: {mean_cv1_score_log}')
print(f'cv scores log-log(partial) model: {cv1_scores_log}')
# Out:
# numerical log-log (partial: most highly skewed features log transformed) model without MiscVal, TotalBsmtSF, and GrLivArea
# mean cv score log-log(partial) model: 0.8507
# cv scores log-log(partial) model: [0.79006354 0.85502    0.87826501 0.86494615 0.8651429 ]

# %%
# append notebook_results
notebook_results.append({
    'Scenario': 'num log-log (partial) model',
    'Mean CV Score': mean_cv1_score_log,
    'CV Scores': cv1_scores_log.tolist()  # Convert to list for better display
})

# %%
# notebook_results

# %% [markdown]
# ## Compare model scores with comoponent and composite porch features

# %%
# create a composite porch area feature
total_porch_features = base_features.copy()
total_porch_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  Fireplaces  GarageYrBlt  \
# 0         0.0      618.0       856         0  ...           1         1939
# 1       393.0      104.0      1049         0  ...           0         1984
#
#    GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         2.0       399.0           0            0              0          0
# 1         1.0       266.0           0          105              0          0
#
#    ScreenPorch  PoolArea
# 0          166         0
# 1            0         0
#
# [2 rows x 28 columns]

# %%
total_porch_features['TotalPorch'] = (
    total_porch_features['OpenPorchSF'] + 
    total_porch_features['EnclosedPorch'] +
    total_porch_features['3SsnPorch'] + 
    total_porch_features['ScreenPorch']
)
total_porch_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageYrBlt  GarageCars  \
# 0         0.0      618.0       856         0  ...         1939         2.0
# 1       393.0      104.0      1049         0  ...         1984         1.0
#
#    GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0       399.0           0            0              0          0          166
# 1       266.0           0          105              0          0            0
#
#    PoolArea  TotalPorch
# 0         0         166
# 1         0         105
#
# [2 rows x 29 columns]

# %%
total_porch_features.drop(columns=['OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch'], inplace=True)

# %%
total_porch_features
# Out:
#       LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0            68.0     7890       1939          1950         0.0       238.0
# 1            42.0     4235       1984          1984       149.0       552.0
# 2            60.0     6060       1930          2007         0.0       737.0
# 3            80.0     8146       1900          2003         0.0         0.0
# 4            70.0     8400       2001          2001         0.0       643.0
# ...           ...      ...        ...           ...         ...         ...
# 2575         68.0     8854       1916          1950         0.0         0.0
# 2576         68.0    13680       1955          1955         0.0         0.0
# 2577         82.0     6270       1949          1950         0.0       284.0
# 2578         68.0     8826       2000          2000       144.0       841.0
# 2579         80.0     9554       1993          1994       125.0       380.0
#
#       BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  BedroomAbvGr  \
# 0            0.0      618.0       856         0  ...             2
# 1          393.0      104.0      1049         0  ...             2
# 2            0.0      100.0      1001         0  ...             2
# 3            0.0      405.0       717       322  ...             2
# 4            0.0      167.0       810       855  ...             3
# ...          ...        ...       ...       ...  ...           ...
# 2575         0.0      952.0       952         0  ...             2
# 2576         0.0        0.0      1733         0  ...             4
# 2577         0.0      717.0      1001      1001  ...             4
# 2578         0.0      144.0       985       857  ...             3
# 2579         0.0      397.0      1065       846  ...             3
#
#       KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  \
# 0                1             4           1         1939         2.0
# 1                1             5           0         1984         1.0
# 2                1             5           0         1930         1.0
# 3                1             6           0         1940         1.0
# 4                1             6           0         2001         2.0
# ...            ...           ...         ...          ...         ...
# 2575             1             4           1         1916         1.0
# 2576             1             8           1         1955         2.0
# 2577             2             8           0         1949         3.0
# 2578             1             7           1         2000         2.0
# 2579             1             8           1         1993         2.0
#
#       GarageArea  WoodDeckSF  PoolArea  TotalPorch
# 0          399.0           0         0         166
# 1          266.0           0         0         105
# 2          216.0         154         0         128
# 3          281.0           0         0         279
# 4          528.0           0         0          45
# ...          ...         ...       ...         ...
# 2575       192.0           0         0         138
# 2576       452.0           0         0           0
# 2577       871.0           0         0           0
# 2578       486.0         193         0          96
# 2579       471.0         182         0          81
#
# [2580 rows x 25 columns]

# %%
# Define base features list
total_porch_features_list = total_porch_features.columns.to_list()
total_porch_features_list
# Out:
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'PoolArea',
#  'TotalPorch']

# %%
# define features and target for modeling
X_totpor = total_porch_features
y = ames['SalePrice']

# %%
# Set up preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', total_porch_features_list)
])

# %%
# fit the model
model_totpor = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', LinearRegression())
    ])

# %%
model_totpor.fit(X_totpor, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['LotFrontage', 'LotArea',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvGrd', 'Fireplaces',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea', 'WoodDeckSF',
#                                                    'PoolArea',
#                                                    'TotalPorch'])])),
#                 ('regressor', LinearRegression())])

# %%
# evaluate the model
cv_scores = cross_val_score(model_totpor, X_totpor, y)

# %%
mean_cv_score = float(round(cv_scores.mean(), 4))
print(f'Model with composite TotalPorch feature, dropping 4 component porch features:')
print(f'mean cv score: {mean_cv_score}')
print(f'cv scores: {cv_scores}')
# Out:
# Model with composite TotalPorch feature, dropping 4 component porch features:
# mean cv score: 0.8278
# cv scores: [0.79252561 0.8328325  0.85868476 0.82228316 0.83279752]

# %%
# # append notebook_results
# notebook_results.append({
#     'Scenario': 'Model with composite TotalPorch feature, dropping 4 component porch features',
#     'Mean CV Score': mean_cv_score,
#     'CV Scores': cv_scores.tolist()  # Convert to list for better display
# })

# notebook_results

# %% [markdown]
# ## Compare model scores with component and composite bathroom features

# %%
base_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  Fireplaces  GarageYrBlt  \
# 0         0.0      618.0       856         0  ...           1         1939
# 1       393.0      104.0      1049         0  ...           0         1984
#
#    GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         2.0       399.0           0            0              0          0
# 1         1.0       266.0           0          105              0          0
#
#    ScreenPorch  PoolArea
# 0          166         0
# 1            0         0
#
# [2 rows x 28 columns]

# %%
bath_features = base_features.copy()
bath_features['TotalBath'] = (
    bath_features['BsmtFullBath'] + 
    bath_features['BsmtHalfBath'] +
    bath_features['FullBath'] + 
    bath_features['HalfBath']
)
bath_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageYrBlt  GarageCars  \
# 0         0.0      618.0       856         0  ...         1939         2.0
# 1       393.0      104.0      1049         0  ...         1984         1.0
#
#    GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0       399.0           0            0              0          0          166
# 1       266.0           0          105              0          0            0
#
#    PoolArea  TotalBath
# 0         0        2.0
# 1         0        3.0
#
# [2 rows x 29 columns]

# %%
bath_features.drop(columns=['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath'], inplace=True)
bath_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageYrBlt  GarageCars  \
# 0         0.0      618.0       856         0  ...         1939         2.0
# 1       393.0      104.0      1049         0  ...         1984         1.0
#
#    GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0       399.0           0            0              0          0          166
# 1       266.0           0          105              0          0            0
#
#    PoolArea  TotalBath
# 0         0        2.0
# 1         0        3.0
#
# [2 rows x 25 columns]

# %%
bath_features_list = bath_features.columns.to_list()
bath_features_list
# Out:
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'TotalBath']

# %%
# define features and target for modeling
X_totbath = bath_features
y = ames['SalePrice']

# %%
# Set up preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', bath_features_list)
])

# %%
# fit the model
model_totbath = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', LinearRegression())
    ])

# %%
model_totbath.fit(X_totbath, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['LotFrontage', 'LotArea',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvGrd', 'Fireplaces',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea', 'WoodDeckSF',
#                                                    'OpenPorchSF',
#                                                    'EnclosedPorch', '3SsnPorch',
#                                                    'ScreenPorch', 'PoolArea',
#                                                    'TotalBath'])])),
#                 ('regressor', LinearRegression())])

# %%
# evaluate the model
cv_scores = cross_val_score(model_totbath, X_totbath, y)

# %%
mean_cv_score = float(round(cv_scores.mean(), 4))
print(f'Model with composite TotalBath feature, dropping 4 component bath features:')
print(f'mean cv score: {mean_cv_score}')
print(f'cv scores: {cv_scores}')
# Out:
# Model with composite TotalBath feature, dropping 4 component bath features:
# mean cv score: 0.8283
# cv scores: [0.79415271 0.83364377 0.85682397 0.82442745 0.83268379]

# %%
# # append notebook_results
# notebook_results.append({
#     'Scenario': 'Model with composite TotalBath feature, dropping 4 component bath features',
#     'Mean CV Score': mean_cv_score,
#     'CV Scores': cv_scores.tolist()  # Convert to list for better display
# })

# notebook_results

# %% [markdown]
# ### Dropping all the component features in lieu of composite (bath and porch)

# %%
composite_base_features = base_features.copy()
composite_base_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  Fireplaces  GarageYrBlt  \
# 0         0.0      618.0       856         0  ...           1         1939
# 1       393.0      104.0      1049         0  ...           0         1984
#
#    GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         2.0       399.0           0            0              0          0
# 1         1.0       266.0           0          105              0          0
#
#    ScreenPorch  PoolArea
# 0          166         0
# 1            0         0
#
# [2 rows x 28 columns]

# %%
composite_base_features['TotalPorch'] = (
    composite_base_features['OpenPorchSF'] + 
    composite_base_features['EnclosedPorch'] +
    composite_base_features['3SsnPorch'] + 
    composite_base_features['ScreenPorch']
)

composite_base_features['TotalBath'] = (
    composite_base_features['BsmtFullBath'] + 
    composite_base_features['BsmtHalfBath'] +
    composite_base_features['FullBath'] + 
    composite_base_features['HalfBath']
)
composite_base_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageCars  GarageArea  \
# 0         0.0      618.0       856         0  ...         2.0       399.0
# 1       393.0      104.0      1049         0  ...         1.0       266.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0            0              0          0          166         0
# 1           0          105              0          0            0         0
#
#    TotalPorch  TotalBath
# 0         166        2.0
# 1         105        3.0
#
# [2 rows x 30 columns]

# %%
composite_base_features.drop(
    columns=[
        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 
        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath'
    ], inplace=True)

# %%
composite_base_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  KitchenAbvGr  TotRmsAbvGrd  \
# 0         0.0      618.0       856         0  ...             1             4
# 1       393.0      104.0      1049         0  ...             1             5
#
#    Fireplaces  GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  PoolArea  \
# 0           1         1939         2.0       399.0           0         0
# 1           0         1984         1.0       266.0           0         0
#
#    TotalPorch  TotalBath
# 0         166        2.0
# 1         105        3.0
#
# [2 rows x 22 columns]

# %%
# define features and target for modeling
X_composite = composite_base_features.copy()
y = ames['SalePrice']

# %%
composite_base_features_list = composite_base_features.columns.to_list()

# %%
# Set up preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', composite_base_features_list)
])

# %%
# fit the model
model_comp = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', LinearRegression())
    ])

# %%
model_comp.fit(X_composite, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['LotFrontage', 'LotArea',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvGrd', 'Fireplaces',
#                                                    'GarageYrBlt', 'GarageCars',
#                                                    'GarageArea', 'WoodDeckSF',
#                                                    'PoolArea', 'TotalPorch',
#                                                    'TotalBath'])])),
#                 ('regressor', LinearRegression())])

# %%
# evaluate the model
cv_scores = cross_val_score(model_comp, X_composite, y)

# %%
mean_cv_score = float(round(cv_scores.mean(), 4))
print(f'Model with both composite Bath and Porch features, dropping 8 component features:')
print(f'mean cv score: {mean_cv_score}')
print(f'cv scores: {cv_scores}')
# Out:
# Model with both composite Bath and Porch features, dropping 8 component features:
# mean cv score: 0.8284
# cv scores: [0.79250939 0.83286663 0.85876069 0.82534545 0.83239619]

# %%
# # append notebook_results
# notebook_results.append({
#     'Scenario': 'Model with both composite Bath and Porch features, dropping 8 component features',
#     'Mean CV Score': mean_cv_score,
#     'CV Scores': cv_scores.tolist()  # Convert to list for better display
# })

# notebook_results

# %% [markdown]
# # Numerical and Categorical Models
# [Contents](#Contents)

# %% [markdown]
# ### Define categorical features

# %%
print(f'number of categorical features: {len(ames.select_dtypes(include=["object"]).columns)}')
categorical_features_list = ames.select_dtypes(include=['object']).columns.to_list()
ames.select_dtypes(include=['object']).columns
# Out:
# number of categorical features: 48
# Index(['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'PoolQC', 'Fence', 'MiscFeature', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
categorical_features = ames[categorical_features_list].copy()
categorical_features.head(2)
# Out:
#   MSSubClass MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# 0         30       RL   Pave  None      Reg         Lvl    AllPub    Corner
# 1        120       RL   Pave  None      Reg         Lvl    AllPub    Inside
#
#   LandSlope Neighborhood  ... GarageQual GarageCond PavedDrive PoolQC Fence  \
# 0       Gtl        SWISU  ...         TA         TA          Y   None  None
# 1       Gtl      Edwards  ...         TA         TA          Y   None  None
#
#   MiscFeature MoSold YrSold SaleType SaleCondition
# 0        None      3   2010      WD         Normal
# 1        None      2   2009      WD         Normal
#
# [2 rows x 48 columns]

# %% [markdown]
# ### Base model with everything
#
# numerical and categorical features, including mc features

# %%
X = numerical_features.drop('SalePrice', axis=1).join(categorical_features)
X.head(2)
# Out:
#    GrLivArea  LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0        856         68.0     7890       1939          1950         0.0
# 1       1049         42.0     4235       1984          1984       149.0
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  GarageQual  \
# 0       238.0         0.0      618.0        856.0  ...          TA
# 1       552.0       393.0      104.0       1049.0  ...          TA
#
#    GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  MoSold  YrSold  \
# 0          TA           Y    None   None         None       3    2010
# 1          TA           Y    None   None         None       2    2009
#
#    SaleType  SaleCondition
# 0       WD          Normal
# 1       WD          Normal
#
# [2 rows x 79 columns]

# %%
y = ames['SalePrice']

# %%
# Set up preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', numerical_features.drop('SalePrice', axis=1).columns.to_list()),
        ('categorical', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_features_list)
])

# %%
# fit the model
model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', LinearRegression())
    ])

# %%
model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['GrLivArea', 'LotFrontage',
#                                                    'LotArea', 'YearBuilt',
#                                                    'YearRemodAdd', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvG...
#                                                    'Utilities', 'LotConfig',
#                                                    'LandSlope', 'Neighborhood',
#                                                    'Condition1', 'Condition2',
#                                                    'BldgType', 'HouseStyle',
#                                                    'OverallQual', 'OverallCond',
#                                                    'RoofStyle', 'RoofMatl',
#                                                    'Exterior1st', 'Exterior2nd',
#                                                    'MasVnrType', 'ExterQual',
#                                                    'ExterCond', 'Foundation',
#                                                    'BsmtQual', 'BsmtCond',
#                                                    'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating', ...])])),
#                 ('regressor', LinearRegression())])

# %%
cv_scores = cross_val_score(model, X, y)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [18, 33, 34] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [17, 30, 43, 46] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [9, 17, 18, 19] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [11, 22] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 6, 11, 18, 19, 29] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
mean_cv_score = float(round(cv_scores.mean(), 4))
print(f'num-cat linear-linear model with everything')
print(f'mean cv score log model: {mean_cv_score}')
print(f'cv scores log model: {cv_scores}')
# Out:
# num-cat linear-linear model with everything
# mean cv score log model: 0.914
# cv scores log model: [0.86743571 0.92265047 0.93065861 0.92360722 0.92584001]

# %%
# append notebook_results
notebook_results.append({
    'Scenario': 'num-cat linear-linear model, all features',
    'Mean CV Score': mean_cv_score,
    'CV Scores': cv_scores.tolist()  # Convert to list for better display
})

# %%
# notebook_results

# %% [markdown]
# # base model on train test data

# %%
X.head(2)
# Out:
#    GrLivArea  LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0        856         68.0     7890       1939          1950         0.0
# 1       1049         42.0     4235       1984          1984       149.0
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  GarageQual  \
# 0       238.0         0.0      618.0        856.0  ...          TA
# 1       552.0       393.0      104.0       1049.0  ...          TA
#
#    GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  MoSold  YrSold  \
# 0          TA           Y    None   None         None       3    2010
# 1          TA           Y    None   None         None       2    2009
#
#    SaleType  SaleCondition
# 0       WD          Normal
# 1       WD          Normal
#
# [2 rows x 79 columns]

# %%
numerical_features.drop('SalePrice', axis=1).columns.to_list()
# Out:
# ['GrLivArea',
#  'LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal']

# %%
# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
# Set up preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', numerical_features.drop('SalePrice', axis=1).columns.to_list()),
        ('categorical', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False), categorical_features_list)
])

# fit the model
model = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('regressor', LinearRegression())
    ])

# %%
# fit model on training data
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['GrLivArea', 'LotFrontage',
#                                                    'LotArea', 'YearBuilt',
#                                                    'YearRemodAdd', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvG...
#                                                    'Utilities', 'LotConfig',
#                                                    'LandSlope', 'Neighborhood',
#                                                    'Condition1', 'Condition2',
#                                                    'BldgType', 'HouseStyle',
#                                                    'OverallQual', 'OverallCond',
#                                                    'RoofStyle', 'RoofMatl',
#                                                    'Exterior1st', 'Exterior2nd',
#                                                    'MasVnrType', 'ExterQual',
#                                                    'ExterCond', 'Foundation',
#                                                    'BsmtQual', 'BsmtCond',
#                                                    'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating', ...])])),
#                 ('regressor', LinearRegression())])

# %%
model.score(X_train, y_train)
print(f'score for training data: {model.score(X_train, y_train)}')
# Out:
# score for training data: 0.9443870958025232

# %%
print(f'score for test data: {model.score(X_test, y_test)}')
# Out:
# score for test data: 0.9106981825104055
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [11, 17, 18, 19, 46] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# # log-linear model, without mc, composite features

# %%
# numerical features for base model, without multicollinear features
base_features.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  Fireplaces  GarageYrBlt  \
# 0         0.0      618.0       856         0  ...           1         1939
# 1       393.0      104.0      1049         0  ...           0         1984
#
#    GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         2.0       399.0           0            0              0          0
# 1         1.0       266.0           0          105              0          0
#
#    ScreenPorch  PoolArea
# 0          166         0
# 1            0         0
#
# [2 rows x 28 columns]

# %%
base_features_list
# Out:
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea']

# %%
# define features and target for modeling, numeric and categorical
X2 = ames[base_features_list].join(ames[categorical_features_list])
y = ames['SalePrice']

# %%
X2.head(2)
# Out:
#    LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         68.0     7890       1939          1950         0.0       238.0
# 1         42.0     4235       1984          1984       149.0       552.0
#
#    BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageQual  GarageCond  \
# 0         0.0      618.0       856         0  ...          TA          TA
# 1       393.0      104.0      1049         0  ...          TA          TA
#
#    PavedDrive  PoolQC  Fence  MiscFeature  MoSold  YrSold  SaleType  \
# 0           Y    None   None         None       3    2010       WD
# 1           Y    None   None         None       2    2009       WD
#
#    SaleCondition
# 0         Normal
# 1         Normal
#
# [2 rows x 76 columns]

# %%
# Set up preprocessor
preprocessor2 = ColumnTransformer(
    transformers=[
        ('numerical', 'passthrough', base_features_list),
        ('onehot', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_features_list)
])

# %%
# fit the model
model2 = Pipeline(
    steps=[
        ('preprocessor2', preprocessor2),
        ('regressor', LinearRegression())
    ])

# %%
model2.fit(X2, np.log10(y))
# Out:
# Pipeline(steps=[('preprocessor2',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['LotFrontage', 'LotArea',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'BedroomAbvGr',
#                                                    'KitchenAbvGr',
#                                                    'TotRmsAbvGrd', 'Fireplaces',
#                                                    'GarageY...
#                                                    'Utilities', 'LotConfig',
#                                                    'LandSlope', 'Neighborhood',
#                                                    'Condition1', 'Condition2',
#                                                    'BldgType', 'HouseStyle',
#                                                    'OverallQual', 'OverallCond',
#                                                    'RoofStyle', 'RoofMatl',
#                                                    'Exterior1st', 'Exterior2nd',
#                                                    'MasVnrType', 'ExterQual',
#                                                    'ExterCond', 'Foundation',
#                                                    'BsmtQual', 'BsmtCond',
#                                                    'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating', ...])])),
#                 ('regressor', LinearRegression())])

# %%
# evaluate the model
cv_scores_with_cat = cross_val_score(model2, X2, np.log10(y))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [18, 33, 34] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [17, 30, 43, 46] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [9, 17, 18, 19] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [11, 22] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 6, 11, 18, 19, 29] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
mean_cv_score_with_cat = float(round(cv_scores_with_cat.mean(), 4))
print(f'numerical-categorical log-linear base model (no composite mc features)')
print(f'mean cv score log model: {mean_cv_score_with_cat}')
print(f'cv scores log model: {cv_scores_with_cat}')
# Out:
# numerical-categorical log-linear base model (no composite mc features)
# mean cv score log model: 0.9156
# cv scores log model: [0.87677974 0.91924517 0.92318485 0.93136373 0.92744137]

# %%
# append notebook_results
notebook_results.append({
    'Scenario': 'num-cat log-linear model, without mc, composite features',
    'Mean CV Score': mean_cv_score_with_cat,
    'CV Scores': cv_scores_with_cat.tolist()  # Convert to list for better display
})

# %%
# notebook_results

# %%
# Create summary table
summary_df = pd.DataFrame(notebook_results)

# veiw summary of models 
print("Summary of All Scenarios:")
summary_df
# Out:
# Summary of All Scenarios:
#                                                                         Scenario  \
# 0                                 num linear-linear model, including mc features
# 1  num linear-linear model, no mc features (MiscVal, TotalBsmtSF, and GrLivArea)
# 2     num log-linear model, no mc features (MiscVal, TotalBsmtSF, and GrLivArea)
# 3                                                    num log-log (partial) model
# 4                                      num-cat linear-linear model, all features
# 5                       num-cat log-linear model, without mc, composite features
#
#    Mean CV Score  \
# 0         0.8277
# 1         0.8278
# 2         0.8471
# 3         0.8507
# 4         0.9140
# 5         0.9156
#
#                                                                                               CV Scores
# 0   [0.793843816346853, 0.8336217009930801, 0.8568616477472124, 0.8213162382700148, 0.8328784733922474]
# 1  [0.7941886310042306, 0.8336632492234609, 0.8569731930524078, 0.8212864751095819, 0.8330885584671347]
# 2    [0.7896966581825936, 0.8538593096400977, 0.872619972201618, 0.859330336412344, 0.8602011438920767]
# 3    [0.7900635444096901, 0.8550199958295697, 0.878265009992304, 0.864946145859404, 0.8651428985520748]
# 4  [0.8674357122978216, 0.9226504668303502, 0.9306586050446611, 0.9236072194536997, 0.9258400058128113]
# 5   [0.8767797355898818, 0.9192451722630199, 0.9231848490817174, 0.931363730545358, 0.9274413692737092]

# %% [markdown]
# Need more num-cat models?

# %% [markdown]
# # Resources
# [Return To Top](#Contents)
#
# **Dean De Cock paper and original data:**
#
# - [Ames, Iowa: Alternative to the Boston Housing Data as an
# End of Semester Regression Project](https://jse.amstat.org/v19n3/decock.pdf)
#
# - [DataDocumentation.txt](https://jse.amstat.org/v19n3/decock/DataDocumentation.txt)
#
# - [Ames Data Dictionary on Github](https://github.com/Padre-Media/dataset/blob/main/Ames%20Data%20Dictionary.txt)
